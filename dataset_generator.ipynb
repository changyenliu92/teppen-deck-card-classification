# %%
# Data preparation
## - Load all the images and create training dataset
## - Create training dataset by performing data augmentation

# %%
# imports
import csv
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# %%
# path variabels
PROJ_PATH = 'D:/Work/IMDA/capstone project/'
GENERATE_FOR_TRAIN = 1
PATH_TRAIN_DATASET = PROJ_PATH + 'dataset/train'
PATH_VALID_DATASET = PROJ_PATH + 'dataset/train'

# %%
# build a hash table with key as file name and value as card title
dict_card_title = dict()
arr_card_title = []
arr_card_code = []
with open(PROJ_PATH + 'dataset/teppen_card_database.csv', newline='') as csvfile:
    row = csv.reader(csvfile, delimiter=',')
    for elem in row:
        dict_card_title[elem[0]] = elem[1]
        arr_card_code.append(elem[0])
        arr_card_title.append(elem[1])

dict_card_image = dict()
numOfClasses = len(dict_card_title)
imgData = []
labels = []
for index, key in enumerate(dict_card_title):
    img = Image.open(PROJ_PATH + 'dataset/images/' + key + '.png')
    dict_card_image[key] = np.asarray(img)
    imgData.append(np.asarray(img))
    labels.append(index)
imgData = np.array(imgData)
labels = np.array(labels)

# %%
y_label = to_categorical(labels, 12)
y_label.shape
# Out:
# (12, 12)

# %%
imgData.shape
# Out:
# (12, 498, 360, 4)

# %%
num_of_samples_to_generate = 20
output_path = PATH_TRAIN_DATASET if GENERATE_FOR_TRAIN else PATH_VALID_DATASET

def generateData(output_path, key, index):
    if os.path.exists(output_path) == 0:
        os.makedirs(output_path)
    x = np.array([imgData[index]])
    y = np.array([y_label[index]])
    count = 0
    for x_batch, y_batch in datagen.flow(x, y, batch_size=1, shuffle=1, save_prefix=key, save_to_dir=output_path):
        count = count + 1
        if count > num_of_samples_to_generate:
            break

# data augmentation on
# 1) brightness
# 2) channel shift
datagen = ImageDataGenerator(
    rescale=1./255, 
    brightness_range=(0.3,0.7), 
    channel_shift_range=100,
    fill_mode='nearest')


if os.path.exists(output_path) == 0:
    os.makedirs(output_path)
for index, key in enumerate(dict_card_title):
    generateData(output_path, key, index)

# %%
# additional augmentation on 
# 1) resizing to get different resolution
print('Starting to retrieve all the images to resize and save...')
for directory in os.listdir(output_path):
    for index, filename in enumerate(os.listdir(output_path + directory)):
        # make sure to only process images
        if filename.lower().endswith(('.png', 'jpg', 'jpeg')) == 0:
            continue
        img = Image.open(output_path + directory + '/' + filename)
        
        width, height = img.size
        target_shrink_scale = [1, 2, 3, 4, 5]
        
        for new_scale in target_shrink_scale:
            new_size = ((int)(width/new_scale), (int)(height/new_scale))
            resized_img = img.resize(new_size)
            save_path = output_path + directory + '/'
            save_filename = directory+'_'+str(index)+'_'+str(new_scale)+'.png'
            resized_img.save(save_path + save_filename)
        
        file_to_remove = output_path + directory + '/' + filename
        print('Removing file['+file_to_remove+']')
        os.remove(file_to_remove)
print('Completed!')
# Out:
# [D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 002/CHUN-LI 002_0_899.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 002/CHUN-LI 002_0_9099.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 002/CHUN-LI 002_0_9501.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_1329.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_2909.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_3275.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_3289.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_3715.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_5074.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_5931.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_6338.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_6523.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_6925.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_7197.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_7483.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_7700.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_7858.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_814.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_8752.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_9386.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_9607.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_9787.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_9907.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 003/CHUN-LI 003_0_9946.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_1176.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_1683.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_2147.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_2411.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_3324.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_3978.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_4808.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_5401.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_6081.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_6316.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_6493.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_6734.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_6855.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_6919.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_7458.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_8286.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_8417.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_8830.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_918.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_934.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 004/CHUN-LI 004_0_9771.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_1443.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_1761.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_2039.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_2648.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_2748.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_3198.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_3999.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_4096.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_4414.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_4752.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_5582.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_6460.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_6824.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_7054.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_7430.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_8808.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_896.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_9470.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_9624.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_9833.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 005/CHUN-LI 005_0_9925.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_1809.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_2160.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_2572.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_3674.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_3755.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_5510.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_5881.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_5971.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_6165.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_6752.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_6966.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_7666.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_8172.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_8249.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_8321.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_855.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_95.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_9638.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_9744.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_9897.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 006/CHUN-LI 006_0_9907.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_1034.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_1119.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_1170.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_1757.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_184.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_1931.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_228.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_2893.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_3097.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_3219.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_4330.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_5173.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_6278.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_6443.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_7249.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_7818.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_8284.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_8463.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_8767.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_8839.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 007/CHUN-LI 007_0_8986.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_1035.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_1073.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_1241.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_1449.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_1676.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_1716.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_1922.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_2973.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_3221.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_3304.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_3644.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_406.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_5845.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_5933.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_6086.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_720.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_7258.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_8151.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_8456.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_8971.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 008/CHUN-LI 008_0_9597.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_2657.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_2989.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_3550.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_3652.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_4471.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_4537.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_4775.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_4947.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_4975.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_5066.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_5227.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_5757.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_6085.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_6089.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_6400.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_6440.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_6652.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_7565.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_7586.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_7837.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 009/CHUN-LI 009_0_7872.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_1295.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_2295.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_3005.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_3071.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_3542.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_4038.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_4492.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_45.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_4997.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_5019.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_5311.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_5374.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_5583.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_5875.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_6090.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_6740.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_7351.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_7500.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_8087.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_8374.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 010/CHUN-LI 010_0_8636.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_1276.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_1618.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_1670.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_1724.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_1796.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_2632.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_289.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_3174.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_3577.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_4768.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_5016.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_6156.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_637.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_656.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_7104.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_843.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_8507.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_9316.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_9542.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_9609.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 011/CHUN-LI 011_0_9851.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_101.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_1203.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_1472.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_1759.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_2127.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_2220.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_2518.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_2789.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_3316.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_3380.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_384.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_3895.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_4232.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_5078.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_5623.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_6128.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_6880.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_7191.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_7557.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_7862.png]
# Removing file[D:/Work/IMDA/capstone project/dataset/train/CHUN-LI 012/CHUN-LI 012_0_8982.png]
# Completed!
